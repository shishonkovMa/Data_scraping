# %% [markdown]
# # Filling the Form

# %%
import requests
import re
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By


# options = Options()
# options.add_argument('--headless')
# driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.10) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
# Out:
# [WDM] - ====== WebDriver manager ======
# 2022-07-08 16:14:04,382 INFO ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# 2022-07-08 16:14:04,433 INFO Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# 2022-07-08 16:14:04,435 INFO Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [/home/matu/.wdm/drivers/chromedriver/linux64/103.0.5060.53/chromedriver] found in cache
# 2022-07-08 16:14:04,651 INFO Driver [/home/matu/.wdm/drivers/chromedriver/linux64/103.0.5060.53/chromedriver] found in cache

# %% [markdown]
# Далее находим элемент и прописываем "send_keys()"
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Получаем следующее:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Аналогично прописываем для других полей
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Теперь нам нужно указать информацию в окнах прокрутки
#
# ![image.png](attachment:image.png)
#
# Для этого:

# %%
from selenium.webdriver.support.select import Select

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Теперь в нужном окне тоже находится число "17"
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Далее по аналогии заполним месяц и год. Однако с месяцем можно поступить двумя разными путями.
#
#  - 1ый (указать численное значение месяца, например, апрель):
#
# ![image.png](attachment:image.png)

# %% [markdown]
#  - 2ой (указать сокращенное название месяца, например, июнь):
#
#  ![image.png](attachment:image.png)

# %% [markdown]
# Далее по аналогии делаем с годом
#
# ![image.png](attachment:image.png)

# %% [markdown]
# В итоге получаем:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Далее нужно выбрать пол. Для этого нужно сымитировать клик.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Сработало
#
# ![image.png](attachment:image.png)

# %% [markdown]
# И последнее, что мы должны сделать - нажать кнопку "Sign Up"
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Прогружается
#
# ![image.png](attachment:image.png)

# %%
driver.quit()
