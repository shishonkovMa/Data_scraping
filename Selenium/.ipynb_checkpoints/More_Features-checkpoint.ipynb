# %% [markdown]
# # More Features

# %%
import requests
import re
from bs4 import BeautifulSoup
import time
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By


# options = Options()
# options.add_argument('--headless')
# driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.10) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
# Out:
# [WDM] - ====== WebDriver manager ======
# 2022-07-08 17:19:59,856 INFO ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# 2022-07-08 17:20:00,048 INFO Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# 2022-07-08 17:20:00,050 INFO Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [/home/matu/.wdm/drivers/chromedriver/linux64/103.0.5060.53/chromedriver] found in cache
# 2022-07-08 17:20:00,287 INFO Driver [/home/matu/.wdm/drivers/chromedriver/linux64/103.0.5060.53/chromedriver] found in cache

# %%
driver.get('https://yandex.ru/')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Перейдем по новому урлу

# %%
driver.get('https://en.wikipedia.org')

# %% [markdown]
# ### Вернемся на предыдущую страницу

# %%
driver.back()

# %% [markdown]
# ### На этом моменте можем открыть новую вкладку и посмотреть "id" этих вкладок

# %%
driver.window_handles
# Out:
# ['CDwindow-8905C1B73F04901966834B5833624DE9']

# %% [markdown]
# ### Не закрывая вкладок, перейдем на страницу яндекса

# %%
driver.switch_to.window('CDwindow-8905C1B73F04901966834B5833624DE9')

# %% [markdown]
# ### Поработаем с cookies

# %%
driver.get_cookies
# Out:
# <bound method WebDriver.get_cookies of <selenium.webdriver.chrome.webdriver.WebDriver (session="e3e36e29e0d205fd5b3b9735d0b61bac")>>

# %% [markdown]
# ### Добавим cookies

# %%
# ?driver.add_cookie

# %% [markdown]
# ### Сделаем скриншот всей страницы

# %%
driver.save_screenshot('screen.png')
# Out:
# True

# %% [markdown]
# ### Проскролить до конца страницы

# %%
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
driver.quit()
