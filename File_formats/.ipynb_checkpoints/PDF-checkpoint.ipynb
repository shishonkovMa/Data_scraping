# %%
import fitz
import tabula

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# doc = fitz.open('... .pdf')

# %%
# doc.pageCount
# doc.getToc()

# %% [markdown]
# ## Get text from 1st page

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Get text from all page in one variable

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## For extract pictures from PDF file and save it in directory

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## How to get tables

# %% [markdown]
# ![image.png](attachment:image.png)
